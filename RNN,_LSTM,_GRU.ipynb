# %% [markdown]
# <a href="https://colab.research.google.com/github/sherf1207/Amit-assignments/blob/main/RNN%2C_LSTM%2C_GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.optimizers import Adam
import time

# %%
df=pd.read_csv("/NFLX.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# 1     12595800
# 2      8981500
# 3      9306700
# 4     16906900
# ...        ...
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400
#
# [1009 rows x 7 columns]

# %% [markdown]
# # LSTM

# %%
x = np.random.rand(1009,7, 1)  # 1000 sequences of length 10
y = np.random.randint(0, 2, 1009)  # Binary labels

# %%
model = Sequential()
model.add(LSTM(64, input_shape = (None, 1), activation='tanh'))
model.add(Dense(1))
model.compile(optimizer= Adam(), loss= 'mean_squared_error', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=20, batch_size= 32)
loss, accuracy = model.evaluate(x_train, y_train, verbose=1)
print("loss= ", loss)
print("accuracy= ", accuracy)
# Out:
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5271 - loss: 0.2478
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4986 - loss: 0.2500
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5032 - loss: 0.2522
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5254 - loss: 0.2498
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5083 - loss: 0.2493
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4956 - loss: 0.2509
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5251 - loss: 0.2493
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5338 - loss: 0.2483
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5283 - loss: 0.2487
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5113 - loss: 0.2507
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5234 - loss: 0.2484
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5196 - loss: 0.2481
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5233 - loss: 0.2503
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5405 - loss: 0.2489
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5249 - loss: 0.2501
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4977 - loss: 0.2500
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5377 - loss: 0.2497
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5418 - loss: 0.2473
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4924 - loss: 0.2575
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5109 - loss: 0.2511
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4869 - loss: 0.2514
# loss=  0.2505705654621124
# accuracy=  0.49814125895500183

# %% [markdown]
# #This is the highest accuracy with the LSTM

# %%
x= np.random.rand(1009, 7, 1)
y= np.random.randint(0, 2, 1009)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

x_train = x_train.reshape(x_train.shape[0], 1, x_train.shape[1])
x_test = x_test.reshape(x_test.shape[0], 1, x_test.shape[1])

# %%
def train_model(model_type, X_train, y_train):
    model = Sequential()

    if model_type == 'RNN':
        model.add(SimpleRNN(64, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh'))
    elif model_type == 'LSTM':
        model.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh'))
    elif model_type == 'GRU':
        model.add(GRU(64, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

    loss, accuracy = model.evaluate(X_train, y_train, verbose=0)
    return accuracy

# %%
rnn_acc = train_model('RNN', x_train, y_train)
lstm_acc = train_model('LSTM', x_train, y_train)
gru_acc = train_model('GRU', x_train, y_train)


print(f"RNN-Accuracy: {rnn_acc:.4f}")
print(f"LSTM-Accuracy: {lstm_acc:.4f}")
print(f"GRU-Accuracy: {gru_acc:.4f}")
# Out:
# RNN-Accuracy: 0.5006
# LSTM-Accuracy: 0.5093
# GRU-Accuracy: 0.5167

# %% [markdown]
# #hybrid code to apply GRU, RNN, LSTM at once
